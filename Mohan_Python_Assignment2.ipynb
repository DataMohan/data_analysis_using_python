# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('C:\\Users\\mohan\\Downloads\\titanic_data.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df = df.dropna()

# %%
df['Age'].plot (kind='hist')

# %%
df['Age'].plot(kind = 'box')

# %%
sns.distplot(df['Fare'])

# %%
sns.jointplot(x=df['Age'], y=df['Fare'])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
newdf = pd.DataFrame([df['Survived'], df['Pclass'], df['Sex'], df['Age'], df['Fare']])

# %%
newdf
# Out:
#               1       3        6       10      11    21    23    27       52   \
# Survived        1       1        0       1       1     1     1     0        1
# Pclass          1       1        1       3       1     2     1     1        1
# Sex        female  female     male  female  female  male  male  male   female
# Age            38      35       54       4      58    34    28    19       49
# Fare      71.2833    53.1  51.8625    16.7   26.55    13  35.5   263  76.7292
#
#               54   ...      835     853    857      862      867      871  \
# Survived        0  ...        1       1      1        1        0        1
# Pclass          1  ...        1       1      1        1        1        1
# Sex          male  ...   female  female   male   female     male   female
# Age            65  ...       39      16     51       48       31       47
# Fare      61.9792  ...  83.1583    39.4  26.55  25.9292  50.4958  52.5542
#
#            872      879     887   889
# ...

# %%
newdf = newdf.T

# %%
sns.pairplot(newdf)

# %%
sns.countplot (x='Sex', data=newdf)

# %%
sns.countplot (x='Pclass', hue = 'Sex', data=newdf)

# %%
sns.countplot (x='Survived', hue = 'Sex', data=newdf)

# %%
sns.countplot (x='Survived', hue = 'Pclass', data=newdf)

# %%
sns.heatmap (df.corr())

# %%
sns.boxplot(x='Pclass',y='Age',data=newdf)

# %%
data2 = pd.read_csv('C:\\Users\\mohan\\Downloads\\BM_data.csv.csv')

# %%
data2.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data2.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
data2 = data2.dropna()

# %%
data2
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# ...              ...          ...              ...              ...
# 8517           FDF53       20.750              reg         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# ...

# %%
data2.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
data2.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0         Dairy  249.8092            OUT049                       1999
# 1   Soft Drinks   48.2692            OUT018                       2009
# 2          Meat  141.6180            OUT049                       1999
# 4     Household   53.8614            OUT013                       1987
# 5  Baking Goods   51.4008            OUT018                       2009
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0      Medium               Tier 1  Supermarket Type1          3735.1380
# ...

# %%
data2['Item_Outlet_Sales'].plot (kind = 'hist')

# %%
data2['Item_MRP'].plot (kind = 'box')

# %%
data2.plot (kind ='scatter', x= 'Item_MRP', y= 'Item_Outlet_Sales')

# %%
sns.distplot(data2['Item_Outlet_Sales'])

# %%
sns.jointplot(x=data2['Item_MRP'], y=data2['Item_Outlet_Sales'])

# %%
sns.pairplot(data2, hue = 'Item_Fat_Content')

# %%
sns.countplot(x='Item_Fat_Content', data = data2)

# %%
sns.countplot(x='Item_Type', data=data2)

# %%
sns.countplot(x='Outlet_Size', data = data2)

# %%
sns.countplot(x='Item_Fat_Content', hue = 'Outlet_Size', data = data2)

# %%
sns.countplot(x='Outlet_Location_Type', data = data2)

# %%
sns.countplot(x='Outlet_Type', hue='Outlet_Size', data = data2)

# %%
sns.countplot(x='Outlet_Size', hue='Item_Fat_Content', data = data2)

# %%
sns.countplot(x='Outlet_Size', hue='Item_Type', data=data2)

# %%
sns.heatmap(data2.corr())

# %%
sns.boxplot(x='Outlet_Location_Type',y='Item_Outlet_Sales',data=data2)

# %%
sns.boxplot(x='Item_Fat_Content',y='Item_MRP',data=data2)

# %%
sns.boxplot(x='Item_Fat_Content',y='Item_Outlet_Sales',data=data2)
